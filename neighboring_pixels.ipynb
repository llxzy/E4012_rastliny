# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df
# Out:
#        Tray ROI name  File X  File Y       430       435       440       445  \
# 0       408    green     219     139  0.183823  0.225632  0.193559  0.200209
# 1       408    green     220     140  0.283425  0.278042  0.317035  0.317755
# 2       408    green     220     141  0.204272  0.196906  0.185487  0.199005
# 3       408    green     221     142  0.289078  0.264584  0.292483  0.266248
# 4       408    green     221     143  0.164338  0.181370  0.140160  0.190784
# ...     ...      ...     ...     ...       ...       ...       ...       ...
# 84139   270     tech     153     288  1.047203  1.634158  1.102072  1.271400
# 84140   270     tech     153     289  2.454699  1.706376  2.039631  2.145784
# 84141   270     tech     153     290  2.096009  2.067439  1.495791  1.287829
# 84142   270     tech     153     291  1.251032  1.665399  0.999726  0.990982
# 84143   270     tech     153     292  1.093209  1.159429  0.886136  1.091705
#
#             450       455  ...       850       855       860       865  \
# 0      0.230949  0.226894  ...  1.031646  1.056320  1.043473  1.055322
# 1      0.288264  0.301890  ...  1.007519  1.017169  1.017592  1.013862
# 2      0.219706  0.215076  ...  1.048977  1.060425  1.040651  1.047068
# 3      0.272298  0.266771  ...  1.044586  1.051080  1.039880  1.039046
# 4      0.212571  0.201590  ...  1.054401  1.061236  1.044481  1.049550
# ...         ...       ...  ...       ...       ...       ...       ...
# 84139  1.462068  1.125655  ...  1.025503  1.024252  1.051773  0.935631
# 84140  1.823796  1.497165  ...  0.953262  1.004952  1.109310  1.012926
# 84141  1.761026  1.327758  ...  0.996630  0.812158  0.850837  0.867156
# 84142  1.069042  0.990556  ...  0.929974  1.086399  1.069519  1.028465
# 84143  1.300388  0.890025  ...  0.905217  0.990001  0.997345  0.999671
#
#             870       875       880       885       890  895
# 0      1.035090  1.023965  1.033526  0.997228  1.004155    1
# 1      1.018148  0.996480  1.023717  1.017925  1.016553    1
# 2      1.023620  1.040414  1.025636  1.015588  1.006813    1
# 3      1.038986  1.011994  1.012592  1.014537  1.037414    1
# 4      1.037166  1.024140  1.028240  1.048446  1.037028    1
# ...         ...       ...       ...       ...       ...  ...
# 84139  0.974163  0.965022  1.090652  0.972417  0.852335    1
# 84140  0.931819  0.922905  1.155726  0.813780  0.969655    1
# 84141  0.850440  0.992200  1.050535  0.767644  0.803021    1
# 84142  0.951145  1.102539  1.089504  1.000030  0.984915    1
# 84143  0.805569  0.834955  0.932299  0.986935  0.987722    1
#
# [84144 rows x 98 columns]

# %%
def mean_across_neighbors(row, neighborhood_size=1):
    """
    row - the row of the dataframe to get values for
    neighborhood size - determines the distance in which to check neighbors
    """
    tray_id = row.Tray
    tray_rows = df.loc[df["Tray"] == tray_id]
    
    possible_X_coords = range(row["File X"] - neighborhood_size, row["File X"] + neighborhood_size, 1)
    possible_Y_coords = range(row["File Y"] - neighborhood_size, row["File Y"] + neighborhood_size, 1)
    
    neighborhood = tray_rows.loc[tray_rows['File X'].isin(possible_X_coords) & tray_rows['File Y'].isin(possible_Y_coords)]
    
    value_columns = [c for c in neighborhood.columns if c not in ['Tray', 'ROI name', 'File X', 'File Y']]
    
    
    for col in value_columns:
        row[col] = np.mean(neighborhood[col])
    
    return row

# %%
df_means = df.apply(lambda row: mean_across_neighbors(row, 1), axis= 1)
df_means
# Out:
#        Tray ROI name  File X  File Y       430       435       440       445  \
# 0       408    green     219     139  0.183823  0.225632  0.193559  0.200209
# 1       408    green     220     140  0.233624  0.251837  0.255297  0.258982
# 2       408    green     220     141  0.243848  0.237474  0.251261  0.258380
# 3       408    green     221     142  0.246675  0.230745  0.238985  0.232626
# 4       408    green     221     143  0.226708  0.222977  0.216322  0.228516
# ...     ...      ...     ...     ...       ...       ...       ...       ...
# 84139   270     tech     153     288  1.788423  2.046508  1.720333  1.958334
# 84140   270     tech     153     289  1.750951  1.670267  1.570852  1.708592
# 84141   270     tech     153     290  2.275354  1.886907  1.767711  1.716807
# 84142   270     tech     153     291  1.673521  1.866419  1.247758  1.139405
# 84143   270     tech     153     292  1.172120  1.412414  0.942931  1.041343
#
#             450       455  ...       850       855       860       865  \
# 0      0.230949  0.226894  ...  1.031646  1.056320  1.043473  1.055322
# 1      0.259607  0.264392  ...  1.019582  1.036745  1.030533  1.034592
# 2      0.253985  0.258483  ...  1.028248  1.038797  1.029122  1.030465
# 3      0.246002  0.240923  ...  1.046781  1.055753  1.040266  1.043057
# 4      0.242434  0.234180  ...  1.049494  1.056158  1.042181  1.044298
# ...         ...       ...  ...       ...       ...       ...       ...
# 84139  1.766528  1.546791  ...  1.089394  1.095966  1.137498  1.078394
# 84140  1.642932  1.311410  ...  0.989382  1.014602  1.080542  0.974278
# 84141  1.792411  1.412461  ...  0.974946  0.908555  0.980074  0.940041
# 84142  1.415034  1.159157  ...  0.963302  0.949278  0.960178  0.947810
# 84143  1.184715  0.940290  ...  0.917595  1.038200  1.033432  1.014068
#
#             870       875       880       885       890  895
# 0      1.035090  1.023965  1.033526  0.997228  1.004155  1.0
# 1      1.026619  1.010222  1.028622  1.007577  1.010354  1.0
# 2      1.020884  1.018447  1.024677  1.016757  1.011683  1.0
# 3      1.031303  1.026204  1.019114  1.015062  1.022113  1.0
# 4      1.038076  1.018067  1.020416  1.031491  1.037221  1.0
# ...         ...       ...       ...       ...       ...  ...
# 84139  1.053488  1.098822  1.053277  1.136150  1.041699  1.0
# 84140  0.952991  0.943963  1.123189  0.893098  0.910995  1.0
# 84141  0.891129  0.957552  1.103130  0.790712  0.886338  1.0
# 84142  0.900792  1.047370  1.070019  0.883837  0.893968  1.0
# 84143  0.878357  0.968747  1.010902  0.993482  0.986319  1.0
#
# [84144 rows x 98 columns]

# %%
df_means.to_csv("data_means.csv")

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
data = df_means.drop(columns='ROI name')
labels = df_means['ROI name']
labels = labels.astype('category')
X_train, X_test, y_train, y_test = train_test_split(data, labels, shuffle=True, test_size=0.2)

# %%
classifier = DecisionTreeClassifier(max_depth=30)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=30)

# %% [raw]
# predictions = classifier.predict(X_test)
# classification_report(y_test, predictions)

# %%
predictions = classifier.predict(X_test)
print(classification_report(y_test, predictions))

# somehow remove the tech?
# Out:
#               precision    recall  f1-score   support
#
#         blue       1.00      1.00      1.00      3625
#          dry       0.97      0.97      0.97      1155
#        green       0.99      0.99      0.99      2150
#         soil       0.99      0.97      0.98      1637
#         tech       1.00      1.00      1.00      8262
#
#     accuracy                           0.99     16829
#    macro avg       0.99      0.99      0.99     16829
# weighted avg       0.99      0.99      0.99     16829
